# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
def haarFWT (signal, level):
    s = .5;                  # scaling -- try 1 or ( .5 ** .5 )

    h = [ 1,  1 ];           # lowpass filter
    g = [ 1, -1 ];           # highpass filter        
    f = len ( h );           # length of the filter

    t = signal;              # 'workspace' array
    l = len (t);           # length of the current signal
    y = [0] * l;             # initialise output

    t = t + [0, 0];        # padding for the workspace

    for i in range ( level ):

        y [ 0:l ] = [0] * l; # initialise the next level 
        l2 = l // 2;         # half approximation, half detail

        for j in range ( l2 ):            
            for k in range ( f ):                
                y [j]    += t [ 2*j + k ] * h [ k ] * s;
                y [j+l2] += t [ 2*j + k ] * g [ k ] * s;

        l = l2;              # continue with the approximation
        t [ 0:l ] = y [ 0:l ] ;

    return y

# %%
img = np.asarray(np.array(Image.open('assets/baboon.png')))

# %%
plt.imshow(img, cmap='gray')

# %%
haarFWT(img, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-4e6b70d89ded> in <module>
# ----> 1 haarFWT(img, 3)
#
# <ipython-input-29-178f28eb1ebe> in haarFWT(signal, level)
#      10     y = [0] * l;             # initialise output
#      11
# ---> 12     t = t + [0, 0];        # padding for the workspace
#      13
#      14     for i in range ( level ):
#
# ValueError: operands could not be broadcast together with shapes (512,512) (2,)

# %%
np.array(0, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-50e39ec69b8f> in <module>
# ----> 1 np.array(0, 0)
#
# TypeError: data type not understood
